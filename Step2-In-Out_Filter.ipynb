# %%
import pandas as pd
import os
import numpy as np
from scipy import signal
import cv2

# %%
def smooth(pix_num):
    win_gauss = signal.gaussian(10,3)
    smooth_pix_num = signal.convolve(pix_num, win_gauss, mode='same', method = 'direct') / win_gauss.sum()
    return(smooth_pix_num)
def edge_detect(smooth_pix_num):
    pix_value = np.asarray(smooth_pix_num)
    pix_thresh = 500
    motion = (pix_value > pix_thresh)
    frames = np.array(range(len(motion)-1))
    In_frame = frames[motion[1:] & ~motion[:-1]]+1
    Out_frame = frames[~motion[1:] & motion[:-1]]+1
    return(In_frame, Out_frame)

# %%
path = r'C:\Users\Daniellab\Desktop\Light_level_videos_second_batch\Data\Step1_Tanvi_Method'
output_path = r'C:\Users\Daniellab\Desktop\Light_level_videos_second_batch\Data\Step2_Tanvi_Method'
data = [(os.path.join(root, name), name[0:-4])
               for root, dirs, files in os.walk(path)
               for name in files
               if name.endswith('.csv')]
data
# Out:
# [('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m10.csv',
#   'L0.1_c-3_m10'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m12.csv',
#   'L0.1_c-3_m12'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m2.csv',
#   'L0.1_c-3_m2'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m20.csv',
#   'L0.1_c-3_m20'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m21.csv',
#   'L0.1_c-3_m21'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m22.csv',
#   'L0.1_c-3_m22'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m23.csv',
#   'L0.1_c-3_m23'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m24.csv',
#   'L0.1_c-3_m24'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m25.csv',
#   'L0.1_c-3_m25'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m27.csv',
#   'L0.1_c-3_m27'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m32.csv',
#   'L0.1_c-3_m32'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m34.csv',
#   'L0.1_c-3_m34'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m37.csv',
#   'L0.1_c-3_m37'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m38.csv',
#   'L0.1_c-3_m38'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m39.csv',
#   'L0.1_c-3_m39'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m40.csv',
#   'L0.1_c-3_m40'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m41.csv',
#   'L0.1_c-3_m41'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m43.csv',
#   'L0.1_c-3_m43'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m44.csv',
#   'L0.1_c-3_m44'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m45.csv',
#   'L0.1_c-3_m45'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m46.csv',
#   'L0.1_c-3_m46'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m47.csv',
#   'L0.1_c-3_m47'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m48.csv',
#   'L0.1_c-3_m48'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m49.csv',
#   'L0.1_c-3_m49'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m5.csv',
#   'L0.1_c-3_m5'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m50.csv',
#   'L0.1_c-3_m50'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m54.csv',
#   'L0.1_c-3_m54'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m57.csv',
#   'L0.1_c-3_m57'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L0.1_c-3_m8.csv',
#   'L0.1_c-3_m8'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m10.csv',
#   'L50_c-3_m10'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m12.csv',
#   'L50_c-3_m12'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m13.csv',
#   'L50_c-3_m13'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m14.csv',
#   'L50_c-3_m14'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m15.csv',
#   'L50_c-3_m15'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m2.csv',
#   'L50_c-3_m2'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m21.csv',
#   'L50_c-3_m21'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m22.csv',
#   'L50_c-3_m22'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m24.csv',
#   'L50_c-3_m24'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m25.csv',
#   'L50_c-3_m25'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m26.csv',
#   'L50_c-3_m26'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m30.csv',
#   'L50_c-3_m30'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m32.csv',
#   'L50_c-3_m32'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m33.csv',
#   'L50_c-3_m33'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m34.csv',
#   'L50_c-3_m34'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m35.csv',
#   'L50_c-3_m35'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m37.csv',
#   'L50_c-3_m37'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m38.csv',
#   'L50_c-3_m38'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m39.csv',
#   'L50_c-3_m39'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m45.csv',
#   'L50_c-3_m45'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m49.csv',
#   'L50_c-3_m49'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m50.csv',
#   'L50_c-3_m50'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m51.csv',
#   'L50_c-3_m51'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m58.csv',
#   'L50_c-3_m58'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m6.csv',
#   'L50_c-3_m6'),
#  ('C:\\Users\\Daniellab\\Desktop\\Light_level_videos_second_batch\\Data\\Step1_Tanvi_Method\\L50_c-3_m9.csv',
#   'L50_c-3_m9')]

# %%
for video in data:
    df = pd.read_csv(video[0])
    filename = video[1]
    
    print('working on ' + filename)
    with open(os.path.join(output_path, 'Step2_SummaryFile.txt'), 'a') as log_text:
        log_text.write('\n' + 'working on ' + filename + '\n')
    
    pix_per_frame = df.NumPixel.values
    smooth_pix_num = smooth(pix_per_frame)
    In, Out = edge_detect(smooth_pix_num)
    
    if In.size > Out.size:
        In = In[:Out.size]
    elif In.size < Out.size:
        Out = Out[1:]
    
    frames_in_view = Out - In
     
    nd = {'In_Frame': In, 'Out_Frame': Out, 'Frames_In_View': frames_in_view}
    new_df = pd.DataFrame(data=nd)
#     new_df.to_csv(output_path + '/' + filename + '_MothInOut.csv')
    
    if frames_in_view.size == 0:
        print('no moth movement detected ' + filename)
        with open(os.path.join(output_path, 'Step2_SummaryFile.txt'), 'a') as log_text:
            log_text.write('\n' + 'no moth movement detected ' + filename + '\n')
    else:
        print('done with ' + filename)
        with open(os.path.join(output_path, 'Step2_SummaryFile.txt'), 'a') as log_text:
            log_text.write('done with ' + filename + '\n')
# Out:
# working on L0.1_c-3_m10
# done with L0.1_c-3_m10
# working on L0.1_c-3_m12
# done with L0.1_c-3_m12
# working on L0.1_c-3_m2
# done with L0.1_c-3_m2
# working on L0.1_c-3_m20
# done with L0.1_c-3_m20
# working on L0.1_c-3_m21
# done with L0.1_c-3_m21
# working on L0.1_c-3_m22
# done with L0.1_c-3_m22
# working on L0.1_c-3_m23
# done with L0.1_c-3_m23
# working on L0.1_c-3_m24
# done with L0.1_c-3_m24
# working on L0.1_c-3_m25
# done with L0.1_c-3_m25
# working on L0.1_c-3_m27
# done with L0.1_c-3_m27
# working on L0.1_c-3_m32
# done with L0.1_c-3_m32
# working on L0.1_c-3_m34
# done with L0.1_c-3_m34
# working on L0.1_c-3_m37
# done with L0.1_c-3_m37
# working on L0.1_c-3_m38
# done with L0.1_c-3_m38
# working on L0.1_c-3_m39
# done with L0.1_c-3_m39
# working on L0.1_c-3_m40
# done with L0.1_c-3_m40
# working on L0.1_c-3_m41
# done with L0.1_c-3_m41
# working on L0.1_c-3_m43
# done with L0.1_c-3_m43
# working on L0.1_c-3_m44
# done with L0.1_c-3_m44
# working on L0.1_c-3_m45
# done with L0.1_c-3_m45
# working on L0.1_c-3_m46
# done with L0.1_c-3_m46
# working on L0.1_c-3_m47
# done with L0.1_c-3_m47
# working on L0.1_c-3_m48
# done with L0.1_c-3_m48
# working on L0.1_c-3_m49
# done with L0.1_c-3_m49
# working on L0.1_c-3_m5
# done with L0.1_c-3_m5
# working on L0.1_c-3_m50
# done with L0.1_c-3_m50
# working on L0.1_c-3_m54
# done with L0.1_c-3_m54
# working on L0.1_c-3_m57
# done with L0.1_c-3_m57
# working on L0.1_c-3_m8
# done with L0.1_c-3_m8
# working on L50_c-3_m10
# done with L50_c-3_m10
# working on L50_c-3_m12
# done with L50_c-3_m12
# working on L50_c-3_m13
# done with L50_c-3_m13
# working on L50_c-3_m14
# done with L50_c-3_m14
# working on L50_c-3_m15
# done with L50_c-3_m15
# working on L50_c-3_m2
# done with L50_c-3_m2
# working on L50_c-3_m21
# done with L50_c-3_m21
# working on L50_c-3_m22
# done with L50_c-3_m22
# working on L50_c-3_m24
# done with L50_c-3_m24
# working on L50_c-3_m25
# done with L50_c-3_m25
# working on L50_c-3_m26
# done with L50_c-3_m26
# working on L50_c-3_m30
# done with L50_c-3_m30
# working on L50_c-3_m32
# done with L50_c-3_m32
# working on L50_c-3_m33
# done with L50_c-3_m33
# working on L50_c-3_m34
# done with L50_c-3_m34
# working on L50_c-3_m35
# done with L50_c-3_m35
# working on L50_c-3_m37
# done with L50_c-3_m37
# working on L50_c-3_m38
# done with L50_c-3_m38
# working on L50_c-3_m39
# done with L50_c-3_m39
# working on L50_c-3_m45
# done with L50_c-3_m45
# working on L50_c-3_m49
# done with L50_c-3_m49
# working on L50_c-3_m50
# done with L50_c-3_m50
# working on L50_c-3_m51
# done with L50_c-3_m51
# working on L50_c-3_m58
# done with L50_c-3_m58
# working on L50_c-3_m6
# done with L50_c-3_m6
# working on L50_c-3_m9
# done with L50_c-3_m9
