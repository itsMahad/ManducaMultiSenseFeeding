# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import cv2
print(cv2.__version__)
import numpy as np
import scipy as sc
# Out:
# 3.4.1

# %%
path = "D:\Moth Learning Project\Flower shape Experiment Data\TipManualDigitization"

# %%
trackframe_filename = 'ManualTipTRacking_DigitizingChart.xlsx'

# %%
frameInfo = pd.read_excel(path + "\\" + trackframe_filename)

# %%
frameInfo
# Out:
#        Name       Date trial                Start  Frame Start  \
# 0   c-1_m13 2018-03-13     0             11:15:00        20070
# 1   c-1_m13 2018-03-13  last  1900-01-01 16:25:00        72450
# 2    c-2_m5 2018-02-20     0             12:40:00        22320
# 3    c-2_m5 2018-02-20  last  1900-01-01 11:10:00        63180
# 4   c-3_m10 2018-03-01     0             11:15:00        20070
# 5   c-3_m10 2018-03-01  last  1900-01-02 11:40:00       106920
# 6  c-10_m11 2018-03-08     0             05:20:00         9360
# 7  c-10_m11 2018-03-08  last             01:41:00       181800
#
#    Digitized Start                 Stop  Frame Stop  Digitized Stop
# 0            20455             12:00:00       21600           21200
# 1            72930  1900-01-01 17:09:00       73962           73020
# 2            22910             13:34:00       24012           23660
# 3            63540  1900-01-01 11:42:00       63756           63630
# 4            20390             12:02:00       21636           21150
# 5           107670             01:00:10      108000          107770
# 6             9860             06:45:00       11610           11280
# 7           181850             01:41:34      182412          182510

# %% [markdown]
# Get the tracks coordinates

# %%
name = 'c-3_m10'
t0_startFrame = 20390
t0_stopFrame = 21150
tlast_startFrame = 107670
tlast_stopFrame = 107770

# %%
filepath = glob.glob(path + "\\" + "*" + name + "xypts.csv")

# %%
xypts = pd.read_csv(filepath[0])
xypts.columns
# Out:
# Index(['pt1_cam1_X', 'pt1_cam1_Y', 'pt2_cam1_X', 'pt2_cam1_Y', 'pt3_cam1_X',
#        'pt3_cam1_Y', 'pt4_cam1_X', 'pt4_cam1_Y', 'pt5_cam1_X', 'pt5_cam1_Y'],
#       dtype='object')

# %%
trial0 = xypts.loc[t0_startFrame:t0_stopFrame,'pt4_cam1_X':'pt4_cam1_Y']
trial_last = xypts.loc[tlast_startFrame:tlast_stopFrame,'pt4_cam1_X':'pt4_cam1_Y']

# %% [markdown]
# Get the video frame

# %%
pathForVideo = "D:\Moth Learning Project\AllVideosForAnalysis\CompliedDataForAnalysis"
videopath = glob.glob(pathForVideo + "\**\\" + name + ".mp4", recursive=True)

# %%
videopath[0]
# Out:
# "D:\\Moth Learning Project\\AllVideosForAnalysis\\CompliedDataForAnalysis\\Tanvi'sData\\2018_03_01\\c-3_m10.mp4"

# %%
vid = cv2.VideoCapture(videopath[0])

width = vid.get(3)
height = vid.get(4)

ret = vid.set(1,1)
print(ret)

ret, frame = vid.read(1)
# Out:
# True

# %% [markdown]
# # Plot the first and last trial tracks with time color coded

# %%
fig, ax = plt.subplots(1,2, figsize = (30,10) )

ax[0].imshow(frame)
t = np.arange(len(trial0.index))
t0= ax[0].scatter(trial0.pt4_cam1_X, trial0.pt4_cam1_Y,
            s= 20, alpha = 0.5, 
            c=t, cmap = "jet")
fig.colorbar(t0, ax= ax[0])
ax[0].plot(trial0.pt4_cam1_X, trial0.pt4_cam1_Y, '-.', c = "whitesmoke", alpha = 0.2)
ax[0].set_xlim(0,width)
ax[0].set_ylim(height, 0)


ax[1].imshow(frame)
t = np.arange(len(trial_last.index))
t_last= ax[1].scatter(trial_last.pt4_cam1_X, trial_last.pt4_cam1_Y,
            s= 20, alpha = 0.5, 
            c=t, cmap = "jet")
fig.colorbar(t_last, ax= ax[1])
ax[1].plot(trial_last.pt4_cam1_X, trial_last.pt4_cam1_Y, '-.', c = "whitesmoke", alpha = 0.2)
ax[1].set_xlim(0,width)
ax[1].set_ylim(height, 0)
# Out:
# (488.0, 0)

# %% [markdown]
# Plot probability of tip in center along radius

# %%
# import all the packages needed for Hough Transform
from skimage import color
from skimage.feature import canny
from skimage.transform import hough_circle, hough_circle_peaks
from skimage.draw import circle_perimeter, circle

# %%
# find center and radius of flower

ret = vid.set(1,1)
# print(ret)
ret, frame = vid.read(1)
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5,5), 0)
# thresh = cv2.threshold(gray, 60 , 255, cv2.THRESH_BINARY)[1]

# Get the edges
edges = canny(blurred, sigma=5) 
# plt.imshow(edges, cmap='gray')

# perform the hough transform to get circles of radii close to 100
hough_radii = np.arange(50, 150, 1)
hough_res = hough_circle(edges, hough_radii)

# Select the most prominent circles
accums, cx, cy, radii = hough_circle_peaks(hough_res, hough_radii,
                                           total_num_peaks=1)

# Draw them
fig, ax = plt.subplots(figsize=(10, 6))
bckgrnd_tmp = color.gray2rgb(frame)
plt.scatter(cx,cy, 20, c="red")
circy, circx = circle_perimeter(cy[0], cx[0], radii[0])
bckgrnd_tmp[circy, circx] = (20, 220, 20)

ax.imshow(bckgrnd_tmp, cmap='gray')

# %%
# center all the tracked points to the flower center and calculate r

new_x_t0 = trial0.pt4_cam1_X.values - cx[0]
new_y_t0 = trial0.pt4_cam1_Y.values - cy[0]
radius_t0 = np.linalg.norm([new_x_t0, new_y_t0], axis = 0)

new_x_tlast = trial_last.pt4_cam1_X.values - cx[0]
new_y_tlast = trial_last.pt4_cam1_Y.values - cy[0]
radius_tlast = np.linalg.norm([new_x_tlast, new_y_tlast], axis = 0)

# %%
useful_r_t0 = radius_t0[~np.isnan(radius_t0)]
useful_r_t0 = useful_r_t0[useful_r_t0 <= radii[0]]

useful_r_tlast = radius_tlast[~np.isnan(radius_tlast)]
useful_r_tlast = useful_r_tlast[useful_r_tlast <= radii[0]]

# %%
fig, ax = plt.subplots(1, 2, sharex = True, sharey = True, figsize = (20,6))

t = np.arange(len(radius_t0))*1/100
ax[0].plot(t, radius_t0/radii[0])

ax[0].set_yticks(np.arange(5), ('0', '1r', '2r', '3r', '4r'))

t_last = np.arange(len(radius_tlast))*1/100
ax[1].plot(t_last, radius_tlast/radii[0])

# %%
fig, ax = plt.subplots(1, 2, sharex = True, sharey = True, figsize = (20,6))

ax[0].hist(useful_r_t0/radii[0])

ax[1].hist(useful_r_tlast/radii[0])
# Out:
# (array([35.,  0.,  1.,  0.,  0.,  1.,  7.,  7.,  6.,  4.]),
#  array([0.07535122, 0.16217665, 0.24900209, 0.33582752, 0.42265296,
#         0.5094784 , 0.59630383, 0.68312927, 0.7699547 , 0.85678014,
#         0.94360558]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Plot the distribution as a function of theta

# %%
xaxis = [1,0]

# %%
theta_t0 = np.arctan2(new_y_t0,new_x_t0)*180/np.pi
copy_theta_t0 = pd.Series(data = theta_t0)
range_theta_t0  = copy_theta_t0.where(copy_theta_t0>0, copy_theta_t0+360)

theta_tlast = np.arctan2(new_y_tlast, new_y_tlast)*180/np.pi
copy_theta_tlast = pd.Series(data = theta_tlast)
range_theta_tlast  = copy_theta_tlast.where(copy_theta_tlast>0, copy_theta_tlast+360)

# %%
fig, ax = plt.subplots(1, 2, sharex = True, sharey = True, figsize = (20,6))

t = np.arange(len(range_theta_t0))*1/100
ax[0].plot(t, range_theta_t0, marker = "o", linestyle = "--")

# ax[0].set_yticks(np.arange(5), ('0', '1r', '2r', '3r', '4r'))

t_last = np.arange(len(range_theta_tlast))*1/100
ax[1].plot(t_last, range_theta_tlast, marker = "o", linestyle = "--")

# %%
# interpl_theta_t0 = range_theta_t0[:-2].interpolate(method = 'spline', order = 3)
# print(len(interpl_theta_t0))

# fig = plt.subplots(figsize = (20,6))
# plt.plot(np.arange(len(interpl_theta_t0)), interpl_theta_t0)

# %%
# unwrap_theta_t0= np.unwrap(interpl_theta_t0.values)

# fig = plt.subplots(figsize = (20,6))
# plt.plot(np.arange(len(unwrap_theta_t0)), unwrap_theta_t0)

# %%
# new_theta_t0= np.unwrap(theta_t0[~np.isnan(theta_t0)])
# new_theta_tlast= np.unwrap(theta_tlast[~np.isnan(theta_tlast)])

# %%
# fig, ax = plt.subplots(1, 2, sharex = True, sharey = True, figsize = (20,6))

# t = np.arange(len(new_theta_t0))*1/100
# ax[0].plot(t, new_theta_t0)

# # ax[0].set_yticks(np.arange(5), ('0', '1r', '2r', '3r', '4r'))

# t_last = np.arange(len(new_theta_tlast))*1/100
# ax[1].plot(t_last, new_theta_tlast)

# %%
fig, ax = plt.subplots(1, 2, sharex = True, sharey = True, figsize = (20,6))

ax[0].hist(range_theta_t0[~np.isnan(range_theta_t0)])
ax[1].hist(range_theta_tlast[~np.isnan(range_theta_tlast)])

ax[0].xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 2))

# %%
# use acos to find angle
# dot_test = np.dot([1,0], [1,1])
# norm_test = np.linalg.norm([1,1])
# angle = np.arccos(dot_test/norm_test)*180/np.pi
# angle

# %%
# dot_t0 = []

# for x,y in zip(new_x_t0, new_y_t0):
#     dotProduct = np.dot([1,0],[x,y])
#     dot_t0.extend([dotProduct])
    
# angle = np.arccos(dot_t0/radius_t0)*180/np.pi

# %%
# fig, ax = plt.subplots(figsize = (10,6))
# ax.plot(angle)

# # ax.yaxis.set_major_locator(plt.MaxNLocator(4))
# ax.yaxis.set_major_locator(plt.MaxNLocator(8))
# # ax.yaxis.set_major_locator(plt.MultipleLocator(np.pi))
# # ax.yaxis.set_minor_locator(plt.MultipleLocator(np.pi / 2))

# %% [markdown]
# # Plot the tracks as heat maps

# %%
t0_heatmap, xedges, yedges = np.histogram2d(trial0.pt4_cam1_X[~np.isnan(trial0.pt4_cam1_X)],
                                            trial0.pt4_cam1_Y[~np.isnan(trial0.pt4_cam1_Y)],
                                            bins=(width,height))

extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
plt.imshow(t0_heatmap.T, extent=[0, width, 0, height], origin='left')

# %%
import numpy as np
import matplotlib.pyplot as plt

#-- Generate Data -----------------------------------------
# Using linspace so that the endpoint of 360 is included...
azimuths = np.radians(np.linspace(0, 360, 20))
zeniths = np.arange(0, 70, 10)

r, theta = np.meshgrid(zeniths, azimuths)
values = np.random.random((azimuths.size, zeniths.size))

#-- Plot... ------------------------------------------------
fig, ax = plt.subplots(subplot_kw=dict(projection='polar'))
ax.contourf(theta, r, values)

plt.show()
