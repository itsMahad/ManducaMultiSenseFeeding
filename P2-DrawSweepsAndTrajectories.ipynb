# %%
import pandas as pd
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob, os

# %%
def TrajectoryTopView(x_gauss, y_gauss, circ_r):
    
    plt.style.use('default')
    
    
    fig = plt.figure()
    ax = plt.gca()
    ax.set_facecolor('black')

    c1 = plt.Circle((0, 0), circ_r, facecolor='linen', alpha = 0.7, 
                    edgecolor='none', zorder = -3)
    ax.add_artist(c1)

    plt.scatter(x_gauss, y_gauss, s=7 , c = 'steelblue', 
               zorder = 1)
    ax.set_aspect('equal', adjustable = 'datalim')
    ax.tick_params(axis = 'both',
                which = 'both',
                bottom = False,
                left = False,
                labelbottom = False,
                  labelleft = False)
    # add this line for representative plots
#     ax.set_ylim(-0.5,2.5)    
    return(fig)

def Sweeps(r_gauss, circ_r):
    fig = plt.figure(figsize = (5,5))
    ax = plt.gca()
    t0 = np.arange(len(r_gauss))*1/100
    plt.plot(t0, r_gauss, c = 'black')
    # add these lines for representative plots
#     plt.xlim(-circ_r*2.5, circ_r*2.5)
#     plt.ylim(-circ_r*2.5, circ_r*2.5)
    return(fig)

# %%
circ_parameters = pd.read_csv('./dataFolders/Output/Centroids_v3/circle_parameters.csv')

# %% [markdown]
# # draw representative

# %%
# plot representative

names_first = ['L0.1_c-3_m23', 'L0.1_c-3_m32', 'L50_c-3_m37', 'L50_c-3_m15']
names_last = ['L0.1_c-3_m23', 'L0.1_c-3_m32', 'L50_c-3_m37', 'L50_c-3_m15']
names = [names_first, names_last]
visitnum = ['FirstVisit/', 'LastVisit/']
figoutpath = r'./dataFolders/Output/Proboscis/RepresentativePlots/'

# %%
# f1, ax = plt.subplots(1,4, figsize = (15,4), sharex = True, sharey = True)
# ax = ax.ravel()

ii = 0
for visit, n  in zip(visitnum, names):
    print(visit)
    
    direc = os.path.join(r"./dataFolders/Output/Proboscis/FilteredTracks/", visit)
    datalist = glob.glob(direc + '*.csv')
    
    for name in n:
        print(name)
        data = [f for f in datalist if name in f][0]
        df = pd.read_csv(data)
        
        circ_r = circ_parameters.loc[circ_parameters.name == name, 'circ_radii'].values
        
        x = df.loc[:, 'x_centered'].values
        y = df.loc[:, 'y_centered'].values
        r = df.loc[:,'r']
        
        f1 = TrajectoryTopView(x, y, circ_r)
        ax1 = f1.gca()
        ax1.set_xlim(-circ_r*5, circ_r*5)
        ax1.set_ylim(-circ_r*5, circ_r*5)
        plt.savefig(figoutpath + visit[:-1] + '_' + name + '_Trajectory.png')
        
        f2 = Sweeps(r, circ_r)
        ax2 = f2.gca()
        ax2.set_ylim(-0.05, 5)
        
        namef2 = figoutpath + visit[:-1] + '_' + name + '_Sweep.png'
        plt.savefig(namef2)
#         plt.savefig('../dataFolders/PaperPipelineOutput/Figures/v2/projectionOnFlower_forTalk_' + visit[:-1] + '_' + name + '.png', f1)
# Out:
# FirstVisit/
# L0.1_c-3_m23
# L0.1_c-3_m32
# L50_c-3_m37
# L50_c-3_m15
# LastVisit/
# L0.1_c-3_m23
# L0.1_c-3_m32
# L50_c-3_m37
# L50_c-3_m15

# %% [markdown]
# # draw ALL the tracks

# %%
visitnum = ['FirstVisit/', 'LastVisit/']
figoutpath = r'./dataFolders/Output/Proboscis/Plots/'

# %%
for visit in visitnum:
    direc = os.path.join(r"./dataFolders/Output/Proboscis/FilteredTracks/", visit)
    datalist = glob.glob(direc + '*.csv')
    
    for data in datalist:
        a, b, c , _ = os.path.basename(data).split('_')
        name = a + '_' + b + '_' + c
        
        df = pd.read_csv(data)
        circ_r = circ_parameters.loc[circ_parameters.name == name, 'circ_radii'].values
        
        x = df.loc[:, 'x_centered'].values
        y = df.loc[:, 'y_centered'].values
        r = df.loc[:,'r']
        
        f1 = TrajectoryTopView(x, y, circ_r)
        ax1 = f1.gca()
        ax1.set_xlim(-circ_r*5, circ_r*5)
        ax1.set_ylim(-circ_r*5, circ_r*5)
        plt.savefig(figoutpath + visit[:-1] + '_' + name + '_Trajectory.png')
        
        f2 = Sweeps(r, circ_r)
        ax2 = f2.gca()
        ax2.set_ylim(-0.05, 5)
        
        namef2 = figoutpath + visit[:-1] + '_' + name + '_Sweep.png'
        plt.savefig(namef2)
# Out:
# C:\Users\Tanvi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Users\Tanvi\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...
